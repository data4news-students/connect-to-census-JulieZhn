# %%
# !pip install censusgeocode

# %%
import glob
import json
import requests
import pandas as pd
from pprint import pprint
# Out:
# /Users/mehtad/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # Census Examples

# %% [markdown]
# This notebook uses the `censusgeocode` package in Python (which is simply a wrapper around the US Census' official Geocoder API) to get census geographies for list of addresses or lat/longs
#
# - https://pypi.org/project/censusgeocode/

# %% [markdown]
# ### Step 1 | Grab your data at the address level

# %%
df = pd.read_csv('311_heat_hotwater.csv')
df
# Out:
# /var/folders/k2/wlk_zlxn02sb9f62n1gwmpw00000gn/T/ipykernel_63242/3253693439.py:1: DtypeWarning: Columns (11,12,13,14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('311_heat_hotwater.csv')
#         Unique Key            Created Date             Closed Date Agency  \
# 0         60551398  03/11/2024 11:59:51 PM                     NaN    HPD
# 1         60550029  03/11/2024 11:59:30 PM                     NaN    HPD
# 2         60555358  03/11/2024 11:59:09 PM                     NaN    HPD
# 3         60554001  03/11/2024 11:58:09 PM                     NaN    HPD
# 4         60548718  03/11/2024 11:56:53 PM                     NaN    HPD
# ...            ...                     ...                     ...    ...
# 196536    58981137  10/01/2023 12:11:25 AM  10/02/2023 02:02:34 AM    HPD
# 196537    59439994  10/01/2023 12:10:52 AM  10/03/2023 12:00:00 AM    HPD
# 196538    58986035  10/01/2023 12:10:09 AM  10/01/2023 08:03:34 PM    HPD
# 196539    59436693  10/01/2023 12:09:48 AM  10/01/2023 12:00:00 AM    HPD
# 196540    59443554  10/01/2023 12:07:32 AM  10/02/2023 12:00:00 AM    HPD
#
#                                               Agency Name  Complaint Type  \
# 0       Department of Housing Preservation and Develop...  HEAT/HOT WATER
# 1       Department of Housing Preservation and Develop...  HEAT/HOT WATER
# 2       Department of Housing Preservation and Develop...  HEAT/HOT WATER
# 3       Department of Housing Preservation and Develop...  HEAT/HOT WATER
# 4       Department of Housing Preservation and Develop...  HEAT/HOT WATER
# ...                                                   ...             ...
# 196536  Department of Housing Preservation and Develop...  HEAT/HOT WATER
# 196537  Department of Housing Preservation and Develop...  Heat/Hot Water
# 196538  Department of Housing Preservation and Develop...  HEAT/HOT WATER
# 196539  Department of Housing Preservation and Develop...  Heat/Hot Water
# 196540  Department of Housing Preservation and Develop...  Heat/Hot Water
#
#              Descriptor         Location Type  Incident Zip  \
# 0        APARTMENT ONLY  RESIDENTIAL BUILDING       11233.0
# 1        APARTMENT ONLY  RESIDENTIAL BUILDING       11106.0
# 2        APARTMENT ONLY  RESIDENTIAL BUILDING       10473.0
# 3        APARTMENT ONLY  RESIDENTIAL BUILDING       10459.0
# 4       ENTIRE BUILDING  RESIDENTIAL BUILDING       11414.0
# ...                 ...                   ...           ...
# 196536  ENTIRE BUILDING  RESIDENTIAL BUILDING       10032.0
# 196537   Apartment Only             Apartment       11221.0
# 196538  ENTIRE BUILDING  RESIDENTIAL BUILDING       10452.0
# 196539  Entire Building         Building-Wide       10452.0
# 196540  Entire Building         Building-Wide       10032.0
#
#              Incident Address  ... Bridge Highway Segment   Latitude  \
# 0          2140 FULTON STREET  ...                    NaN  40.678309
# 1       31-35 CRESCENT STREET  ...                    NaN  40.764684
# 2       1965 LAFAYETTE AVENUE  ...                    NaN  40.822300
# 3         919 PROSPECT AVENUE  ...                    NaN  40.821710
# 4            84-10 153 AVENUE  ...                    NaN  40.666377
# ...                       ...  ...                    ...        ...
# 196536   76 ST NICHOLAS PLACE  ...                    NaN  40.829462
# 196537      441 WILSON AVENUE  ...                    NaN  40.693805
# 196538   15 CLARKE PLACE EAST  ...                    NaN  40.838102
# 196539   15 EAST CLARKE PLACE  ...                    NaN  40.838102
# 196540   76 ST NICHOLAS PLACE  ...                    NaN  40.829462
#
#         Longitude                                  Location Zip Codes  \
# 0      -73.911508   (40.67830884414116, -73.91150841210155)   13516.0
# 1      -73.927184   (40.76468368198577, -73.92718359841146)   16863.0
# 2      -73.856192   (40.82230025720139, -73.85619211834099)   11611.0
# 3      -73.900789  (40.821710476862634, -73.90078928961124)   10937.0
# 4      -73.849975   (40.66637663749487, -73.84997505769617)   15314.0
# ...           ...                                       ...       ...
# 196536 -73.940797  (40.829461589531974, -73.94079691863257)   12428.0
# 196537 -73.913590  (40.693804667081345, -73.91359021281768)   18181.0
# 196538 -73.918274   (40.83810190786086, -73.91827438644238)   10930.0
# 196539 -73.918274   (40.83810190786086, -73.91827438644238)   10930.0
# 196540 -73.940797  (40.829461589531974, -73.94079691863257)   12428.0
#
#        Community Districts Borough Boundaries City Council Districts  \
# 0                     55.0                2.0                   17.0
# 1                     39.0                3.0                    4.0
# 2                     58.0                5.0                   31.0
# 3                     34.0                5.0                   43.0
# 4                     62.0                3.0                   41.0
# ...                    ...                ...                    ...
# 196536                37.0                4.0                   36.0
# 196537                42.0                2.0                   37.0
# 196538                50.0                5.0                   42.0
# 196539                50.0                5.0                   42.0
# 196540                37.0                4.0                   36.0
#
#         Police Precincts Police Precinct
# 0                   46.0            46.0
# 1                   72.0            72.0
# 2                   26.0            26.0
# 3                   25.0            25.0
# 4                   64.0            64.0
# ...                  ...             ...
# 196536              19.0            19.0
# 196537              53.0            53.0
# 196538              27.0            27.0
# 196539              27.0            27.0
# 196540              19.0            19.0
#
# [196541 rows x 47 columns]

# %% [markdown]
# ### Step 2 | Geoode Lat/Long if they're not already present
#
# It already exists in this dataset. Census geocode has a function to go from addresss --> lat/long, but I haven't had time to implement it here. This dataset already has lat/longs. Message me if you're struggling with this step.

# %% [markdown]
# ### Step 3 | Get Census Geographies

# %%
# Code adapted from:
# https://gis.stackexchange.com/questions/363830/applying-the-censusgeocode-package-to-an-entire-dataframe-of-geocoded-data
# Defines a geocode function that accepts lat/long and spits out geographies
# The code then runs that funciton in parllel (for speed).

import pandas as pd
import censusgeocode as cg
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm

import requests_cache
cache = requests_cache.CachedSession("geocode_cache", backend="filesystem")

def geocode(lat, lng):
    try:
        url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
        params = {
            "x": lng,
            "y": lat,
            "benchmark": "Public_AR_Census2020",
            "vintage": "Census2020_Census2020",
            "format": "json"
        }
        response = cache.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        census = data['result']['geographies']['Census Blocks'][0]
        return census
    except Exception as e:
        print(f"Error geocoding ({lat}, {lng}): {e}")
        return None

def bulk_geocode(latitudes, longitudes):
    """
    Geocode a list of latitudes and longitudes in parallel (for speed).
    """

    with ThreadPoolExecutor() as tpe:
        latitudes = df['Latitude']
        longitudes = df['Longitude']
        mapped_results = tpe.map(geocode, latitudes, longitudes)
        data = list(tqdm(mapped_results, total=len(df)))

    return pd.DataFrame(data)

census_geos_df = bulk_geocode(df['Latitude'], df['Longitude']) 
census_geos_df.head()

# %%
to_keep = ['GEOID', 'STATE', 'COUNTY', 'TRACT', 'BLOCK']
census_geos_df = census_geos_df[to_keep]
census_geos_df

# %%
df_with_geos = pd.concat(
    [ 
        df.reset_index(drop=True),
        census_geos_df.reset_index(drop=True)
    ], 
    axis=1)

df_with_geos.head()

# %% [markdown]
# # Step 4 | Pick a geographical level and get Census data
# Do you want Census data at the state level? county? tract? block?
#
# 1. Pick a geographical level.
# 2. See `census-example.ipynb` if you want to learn how to get Census data at your desired level

# %% [markdown]
# # Hope that helps!
